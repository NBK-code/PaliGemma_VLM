# %% [markdown]
# Paligemma-3b-pt-224 model

# %%
import torch

# %%
x = torch.rand(2,3,4,5)
print(x.shape)
# Out:
# torch.Size([2, 3, 4, 5])

# %%
y = x.flatten(2)
print(y.shape)
# Out:
# torch.Size([2, 3, 20])

# %%
print(y.size())
# Out:
# torch.Size([2, 3, 20])

# %%
x = torch.rand(1,2)
print(x.shape)
# Out:
# torch.Size([1, 2])

# %%
x = x.unsqueeze(-1)
print(x.shape)
# Out:
# torch.Size([1, 2, 1])

# %%
x = x.expand(-1, -1, 4)
print(x.shape)
# Out:
# torch.Size([1, 2, 4])

# %%
mask = torch.tensor([True,True,True,False,False,False])
text_1 = torch.tensor([2,2,2,2,2,2])
text_2 = torch.tensor([3,3,3,3,3,3])

y = torch.where(mask, text_1, text_2)

print(y)
# Out:
# tensor([2, 2, 2, 3, 3, 3])

# %%
mask = torch.tensor([True,True,True,False,False,False, False, True])
text_1 = torch.tensor([20,20,20,20,20,20,20,20])
text_2 = torch.tensor([1,2,3,4,5,6])
print(text_1.masked_scatter(mask, text_2))
# Out:
# tensor([ 1,  2,  3, 20, 20, 20, 20,  4])
